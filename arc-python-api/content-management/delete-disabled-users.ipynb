# %% [markdown]
# # Delete Disabled Users

# %% [markdown]
# Find all disabled users in the org and check if they own content. Store a list of disabled users that own no content. Then, delete all disabled users on list

# %%
import pandas as pd
from IPython.display import display

import arcgis
from arcgis.gis import GIS

# %% [markdown]
# #### Connect to ArcGIS Online

# %%
c3GIS = GIS(profile='aolson_prfl2')
c3GIS.users.me
